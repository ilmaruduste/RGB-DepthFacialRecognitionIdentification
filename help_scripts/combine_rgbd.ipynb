# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
rgb_image = cv.imread('./picture_data/example_picture_rgb.png', cv.COLOR_BGR2RGB)
rgb_image = np.flip(rgb_image, axis=-1) 
depth_image = cv.imread('./picture_data/example_picture_d.png')

# %%
plt.imshow(rgb_image)

# %%
processed_depth_image = depth_image*25
plt.imshow(processed_depth_image)

# %%
depth_image.max()
# Out:
# 11

# %%
combined_image = rgb_image * depth_image/10
plt.imshow(combined_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cv.imwrite("./picture_data/example_picture_d_processed.png", processed_depth_image)
# Out:
# True
